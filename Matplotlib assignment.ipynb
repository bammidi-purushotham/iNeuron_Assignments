# %% [markdown]
# # Assignment 09

# %% [markdown]
# ## Scipy

# %% [markdown]
# ### We have the min and max temperatures in a city In India for each months of the year. We would like to find a function to describe this and show it graphically, the dataset given below.

# %% [markdown]
# Data
#
# Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
#
# Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18

# %%
import numpy as np
import matplotlib.pyplot as plt

max_temp = np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
min_temp = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])

# %%
months = np.arange(12)

plt.figure(figsize=(4,3))
plt.scatter(months, max_temp)
plt.scatter(months, min_temp)
plt.xlabel("Months")
plt.ylabel("Max & Min Temperatures")
# Out:
# Text(0, 0.5, 'Max & Min Temperatures')

# %% [markdown]
# ### Fitting it in periodic function

# %%
from scipy import optimize

# Creating function
def yearly_temperatures(times, avg, ampl, time_offset):
    return (avg
            + ampl * np.cos((times + time_offset) * 2 * np.pi / times.max()))

res_max, cov_max = optimize.curve_fit(yearly_temperatures, months, max_temp, [20, 10, 0])
res_min, cov_min = optimize.curve_fit(yearly_temperatures, months, min_temp, [-40, 20, 0])

# %% [markdown]
# Plotting the Fit

# %%
days = np.linspace(0, 12, num=365)

plt.figure(figsize=(8,6))
plt.scatter(months, max_temp)
plt.plot(days, yearly_temperatures(days, *res_max))
plt.scatter(months, min_temp)
plt.plot(days, yearly_temperatures(days, *res_min))
plt.xlabel('Month')
plt.ylabel('Temperature ($^\circ$C)')

plt.show()

# %% [markdown]
# ## Visualization using Matplotlib

# %% [markdown]
# Reading the data

# %%
import pandas as pd

url="https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv"
titanic = pd.read_csv(url)

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# **1. Create a pie chart presenting the male/female proportion**

# %%
gender = titanic['sex'].astype('category')
gender = gender.cat.codes

plt.pie(gender.value_counts(), labels = titanic['sex'].unique(), autopct='%1.1f%%')
plt.title('Male/Female Proportion')
plt.axis('equal')
plt.show()

# %% [markdown]
# **2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender**

# %%
plt.figure(figsize=(8,5))
plt.scatter(titanic['age'], titanic['fare'], c = gender)
plt.xlabel("Age")
plt.ylabel("Fare Paid")
plt.show()
